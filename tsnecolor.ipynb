# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#myfile = pd.read_csv('test.txt', delimiter="\t")
myfile = pd.read_csv('tsne.txt', delimiter="\t")

# %%
myfile.iloc[2]
# Out:
# CellID                       SRX2003964_ACTGACGA
# V1                                      -20.1567
# V2                                       8.24294
# ScaleFactor                              50.7537
# ID             SRX2003964_2_filterReads.ACTGACGA
# INS                                      50.7537
# KRT19                                    152.261
# PPY                                            0
# GCG                                      862.813
# MAFB                                           0
# SST                                      456.783
# PRSS1                                          0
# MAFA                                           0
# CellType                                    duct
# PPY.Log10                              -Infinity
# Name: 2, dtype: object

# %%
x.head(5)
# Out:
# 0    12.734853
# 1   -46.209343
# 2   -20.156716
# 3    19.987510
# 4    -6.559584
# Name: V1, dtype: float64

# %%
x=myfile['V1']
y=myfile['V2']
celltype=myfile['CellType']

# %%
plt.scatter(x, y, c=myfile['PPY'])

# %%
#color the dots by categorial value
sns.lmplot(x="V1", y="V2", data=myfile, hue='CellType',fit_reg=False, legend=False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#color the dots by numeric value continuously
plt.scatter(myfile.V1, myfile.V2, alpha = .8, c = myfile.PPY, cmap = 'seismic')
cbar = plt.colorbar()

# %%
#color the scatter plot by value from another file
file2 = pd.read_csv('file2.txt', delimiter="\t")

# %%
plt.scatter(myfile.V1, myfile.V2, alpha = .8, c = file2.testvalue, cmap = 'seismic')
cbar = plt.colorbar()

# %%
df = sns.load_dataset('iris')

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='petal_length', legend=False)

# Move the legend to an empty part of the plot
#plt.legend(loc='lower right')

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.scatter(df.sepal_length, df.sepal_width, alpha = .8, c = df.petal_length, cmap = 'seismic')
cbar = plt.colorbar()
